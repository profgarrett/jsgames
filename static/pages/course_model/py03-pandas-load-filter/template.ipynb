# %% [markdown]
# # Pandas Practice Problems
#
# Each section contains a problem. Write your code in the cell below each prompt.

# %%
# You may need to install pandas if you have not already done so.
# If so, uncomment and run the following line:

# %pip install pandas

# %% [markdown]
# ## 1. Load a CSV file
#
# - The file is named 'students.csv'
# - Load into a DataFrame called `df_raw`
# - Use read_csv without any other parameters.
#
# Display the first 5 rows of the DataFrame.
#
# What went wrong?

# %% [markdown]
# ## 2. Fix the load with skiprows parameter.

# %% [markdown]
# ## 3. Remove None Values
#
# Create a clean version of the df_raw DataFrame called df.
# Use filter and the notnull() function to remove any rows with missing values.
# Use filtering techniques covered in class.
# Do not use more advanced functions like dropna().

# %% [markdown]
# ## 4. Remove Invalid Ages
#
# Look at the age column. Do you see any invalid ages?

# %% [markdown]
# ## 5. Filter to school age
#
# Create a new DataFrame called df_school_age that only contains students
# with ages between 5 and 18 (inclusive).

# %%
df_school_age

# %% [markdown]
# ## 6. Find the average age of the school age students.
#
# Use np.mean(), np.mode(), and np.median() to find the average ages of the students in the df_school_age DataFrame.
# Save each to a variable.
# Print each age.

# %% [markdown]
# ## 7. Reset index
#
# Print the df_school_age DataFrame, then reset the index so that it starts at 0 and increments by 1. Print it to compare the outputs.

# %% [markdown]
# ## 8. Print the ages column (as a series)
