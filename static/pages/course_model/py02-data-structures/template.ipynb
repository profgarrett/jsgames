# %% [markdown]
# # Practice Problems: Python Sequences and Collections

# %%
# Install dependencies
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Lists

# %% [markdown]
# 1. Create a list of five numbers and print the second element.

# %%
# Your answer here

# %% [markdown]
# 2. Create a list of five numbers and print the 2nd to 4th elements with slicing.

# %%
# Your answer here

# %% [markdown]
# 3. Create a list of five numbers and print the 3rd to last elements with slicing.

# %%
# Your answer here

# %% [markdown]
# 4. Create a list of five numbers and print the 2nd to last and last elements.

# %%
# Your answer here

# %% [markdown]
# 5. Replace the last item in a list with 100.

# %%
# Your answer here

# %% [markdown]
# 6. Remove the first element from a list with pop.

# %%
# Your answer here

# %% [markdown]
# 7. Add 44 to the end of the list

# %%
# Your answer here

# %% [markdown]
# 8. Use del to remove the 3rd item in the list.

# %%
# Your answer here

# %% [markdown]
# 9. Print the 3rd and 5th items in a list.

# %%
# Your answer here

# %% [markdown]
# 10. Use slicing to print every other element in a list.

# %%
# Your answer here

# %% [markdown]
# 11. Concatenate two lists with + and print the result.

# %%
# Your answer here

# %% [markdown]
# ## Numpy Arrays

# %% [markdown]
# 1. Create a numpy array of numbers from 1 to 5 and print it.

# %% [markdown]
# 2. Add 10 to every element in a numpy array.

# %%
# Your answer here

# %% [markdown]
# 3. Multiply every element in a numpy array by 2.

# %%
# Your answer here

# %% [markdown]
# 4. Calculate the mean and standard deviation of a numpy array.

# %%
# Your answer here

# %% [markdown]
# 5. Use boolean indexing to select all even numbers in a numpy array. Hint: use `% 2` to find the mod (remainder).

# %%
# Your answer here

# %% [markdown]
# 6. Sum all elements in a numpy array.

# %%
# Your answer here

# %% [markdown]
# 7. Use max to find the maximum value in a numpy array.

# %%
# Your answer here

# %% [markdown]
# ## Dictionaries

# %% [markdown]
# 1. Create a dictionary mapping three names to ages. Print the age for one name.

# %%
# Your answer here

# %% [markdown]
# 2. Add a new key-value pair to a dictionary.

# %%
# Your answer here

# %% [markdown]
# 3. Update the value for an existing key in a dictionary.

# %%
# Your answer here

# %% [markdown]
# 4. Remove a key from a dictionary with pop and print the result.

# %%
# Your answer here

# %% [markdown]
# 5. Use a for loop to print all keys in a dictionary. Hint: use d.keys() or d.items()

# %%
# Your answer here

# %% [markdown]
# 6. Use a for loop to print all values in a dictionary. Hint: use `d.values()`.

# %%
# Your answer here

# %% [markdown]
# 1. Print all key-value pairs in a dictionary using items().

# %%
# Your answer here

# %% [markdown]
# ## Tuples

# %% [markdown]
# 1. Create a tuple of three strings and print the first one.

# %%
# Your answer here

# %% [markdown]
# 2. Try to change an element in a tuple (what happens?).

# %%
# Your answer here

# %% [markdown]
# 3. Use tuple unpacking to assign three values to three variables in a single line

# %%
# Your answer here

# %% [markdown]
# 4. Check if a value exists in a tuple using `in`.

# %%
# Your answer here

# %% [markdown]
# ## General

# %% [markdown]
# 1. Explain when you would use a numpy array instead of a list.

# %%
# Your answer here

# %% [markdown]
# 2. Compare the performance of summing a large list vs. a numpy array (use %timeit in Jupyter).

# %%
# Your answer here
import numpy as np
large_list = list(range(1000000))

# %timeit sum(large_list)
# %timeit np.array(large_list).sum()

# %% [markdown]
# 3. Explain the difference between mutable and immutable types in Python.

# %%
# Your answer here
