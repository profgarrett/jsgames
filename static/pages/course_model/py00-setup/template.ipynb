# %% [markdown]
# # py00 Template File

# %%
# Script to install required packages for the course
# %pip install ipykernel pandas numpy matplotlib seaborn scikit-learn jupyter openpyxl

# %%
# After running the cell above, this code should work properly.
import sys
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print("Python:", sys.version)
print("Interpreter:", sys.executable)
print("pandas:", pd.__version__)
print("All good.")
