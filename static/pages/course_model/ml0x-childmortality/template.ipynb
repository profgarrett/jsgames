# %% [markdown]
# # Child Mortality

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = ?
df = pd.read_csv(path, skiprows=?)

df

# %% [markdown]
# ## Mortality Rate for Infants and Toddlers

# %%
# Create a filter of True/False values 
df_kids_filter = df['?'] == '?'
df_kids = df[df_kids_filter].copy()

df_kids

# %%
# Plot the data using a line graph. Use the field names from df_kids as your x and y.
sns.lineplot(data=df_kids, x=?, y=?)

# %%
# Which year had the biggest drop in death rate for this group?
biggest_drop = 0
biggest_drop_year = None

for i, row in df_kids.iterrows():
    # Skip the first row since it has no prior year to compare
    if i == ?:
        continue

    this_year_rate = row.death_rate
    last_year_rate = ?
    drop = ?
    if drop > biggest_drop:
        biggest_drop = ?
        ? = row['year']

# show your results as a percentage instead of a raw number.

print("The year", biggest_drop_year, "had the biggest drop in death rate of", biggest_drop, "deaths per 1000 children aged 1-4 years.")

# %%
# Which year had the biggest increase in death rate? Write your answer as a comment below.

# %% [markdown]
# ## What about teenagers?
#
# Note that there is not a perfectly-matching group. Find the best option from the available age groups in the dataset.

# %% [markdown]
# ## Which year had the biggest drop in death rate?
# ## What was the cause of the prior year change in death rate?
#
# Write your answer as markdown. Do some internet research to find out what happened.
