# %% [markdown]
# # Recognize Changes Template

# %%
# Problem 1
import pandas as pd

df = pd.DataFrame({'student_id': [1, 2, 3],
                    'name': ['Alice', 'Bob', 'Charlie'],
                   'score': [85, 90, 78]})


df2
# Out:
#    student_id  exam_score  passed
# 0           1          85    True
# 1           2          90    True
# 2           3          78   False

# %%
# Problem 2
import pandas as pd

df = pd.DataFrame({'order_id': [1, 2, 3],
                    'name': ['Alice', 'Bob', 'Charlie'],
                   'amount': [250, 120, 300]})


df2
# Out:
#    order_id     name  amount
# 0         1    Alice     250
# 2         3  Charlie     300

# %%
# Problem 3
import pandas as pd
import numpy as np

df_q = pd.DataFrame({'product': ['A', 'B'],
                     'Q1': [50, 30],
                        'Q2': [60, 40]})
df_price = pd.DataFrame({'product': ['A', 'B', 'C'],
                         'price': [10, np.nan, 99]})


df2
# Out:
#   product  price quarter  sales
# 0       A   10.0      Q1     50
# 1       B   15.0      Q1     30
# 2       A   10.0      Q2     60
# 3       B   15.0      Q2     40

# %%
# Problem 4
import pandas as pd
import numpy as np

df = pd.DataFrame({'region': ['East', 'East', 'West', 'West'],
                   'sales_rep': ['Alice', 'Bob', 'Charlie', 'David'],
                   'sales': [200, 150, 300, 250]})


df2
# Out:
#         total_sales
# region
# East            350
# West            550

# %%
# Problem 5
import pandas as pd
import numpy as np

df = pd.DataFrame({'employee': ['Alice', 'Alice', 'Bob', 'Bob', 'Charlie'],
                   'quarter': ['Q1', 'Q2', 'Q1', 'Q2', 'Q1'],
                   'sales': [200, 250, 150, 300, 400]})


df2
# Out:
#   employee     Q1     Q2
# 0    Alice  200.0  200.0
# 1      Bob    NaN  300.0

# %%
# Problem 6
import pandas as pd
import numpy as np

df_students = pd.DataFrame({'id': [1, 2, 3, 4, 5, 6, 7],
                            'name': ['Tim', 'Tim', 'Bob', 'Bob', 'Sarah', '?', '?'],
                            'status': ['pending', 'pending', 'Done', 'Done', 'Unknown', 'Done', 'pending'],
                            'units': [1, 2, 1, 1, 1, 1, 1]})


df_students2
# Out:
# status  Done  Unknown  pending
# name
# Bob      1.0      NaN      NaN
# Sarah    NaN      1.0      NaN
# Tim      NaN      NaN      1.5
