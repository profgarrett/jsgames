# %%
# Installation code
# %pip install seaborn matplotlib

# %% [markdown]
# # Visualization Problem

# %% [markdown]
# Question 1: What species of penguin has the longest median flipper length?
#
# Question 2: What species AND gender of penguin has the longest median flipper length? Answer as 'Species Male' or 'Species Female'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

df = sns.load_dataset('penguins')

df

# %% [markdown]
# Question 3: Which island has the most males?  Hint: filter, and then visualize.

# %% [markdown]
# Question 4: Look at the flights dataset for the 1950-1960 flight data. Can we say with certainty that 1958 had more passengers than 1957? Assume that the data is a sample, and not a complete population.
#
# Hint: you can filter the dataframe with something like:
# df = df[(df["field"] >= value) & (df["field"] <= value)]
#
# Note that we use & instead of and, and | instead of or when doing filtering for a dataframe.

# %% [markdown]
# Question 5: Do Chinstrap penguins have a positive relationship between body mass and bill length?

# %% [markdown]
# Question 6: Excluding penguins who live on Dream island, do male penguins have a higher median body mass than female penguins?
#
# Question 7: Excluding penguins who live on Dream island, is the median body mass of male penguins greater than the top 75% of female penguins?

# %% [markdown]
# Question 8: looking at all penguin species, should we consider flipper length a normally distributed variable?

# %% [markdown]
# Question 9: looking at all penguin species, which variable has the most outliers?

# %% [markdown]
# Question 10: What variables are more predictive of body mass? Hint: visualize the relationship between body mass and all other variables, and see which ones have the strongest relationship. You can also use a pairplot to visualize all relationships at once.
