# %% [markdown]
# # Snow Predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = '?'
sheet = '?'
df_raw = pd.read_excel(?, sheet_name=?)

df_raw
# Out:
#            station                    name  prcp  snow  snwd  tmax  tmin  \
# 0      USC00462523      DUNMORE 1 N, WV US  0.20   0.0   0.0   7.2  -1.7
# 1      USC00462523      DUNMORE 1 N, WV US  0.00   0.0   0.0  13.9  -2.2
# 2      USC00462523      DUNMORE 1 N, WV US  0.00   0.0   0.0  13.9  -1.7
# 3      USC00462523      DUNMORE 1 N, WV US  0.07   0.0   0.0  16.7   1.7
# 4      USC00462523      DUNMORE 1 N, WV US  0.00   0.0   0.0  14.4   0.0
# ...            ...                     ...   ...   ...   ...   ...   ...
# 19691  US1WVPC0001  ARBOVALE 0.8 NW, WV US  0.81   NaN   NaN   NaN   NaN
# 19692  US1WVPC0001  ARBOVALE 0.8 NW, WV US  0.54   NaN   NaN   NaN   NaN
# 19693  US1WVPC0001  ARBOVALE 0.8 NW, WV US  0.73   NaN   NaN   NaN   NaN
# 19694  US1WVPC0001  ARBOVALE 0.8 NW, WV US  1.11   2.2   NaN   NaN   NaN
# 19695  US1WVPC0001  ARBOVALE 0.8 NW, WV US  0.00   0.0   NaN   NaN   NaN
#
#           month   year day_of_month
# 0       month_1  y2023  01 of month
# ...

# %%
# Data cleanup

# Create a clean copy of the dataframe to make our changes
df = ?.copy()

# Only include Canaan Valley data.
canaan_filter = df['name'] == ?
df = df[canaan_filter].copy()

# Convert tmin and tmax to fahrenheit
df['tmin'] = [temp * 1 for temp in df['tmin']]
df['tmax'] = ?

# Create a year column
# Drop the text using string slicing, then use int to convert to int
df['y'] = [int(y[1:]) for y in df['year']]
df['m'] = [int(m[6:]) for m in df['month']]
df['d'] = [int(d[:2]) for d in df['day_of_month']]

# Filter to only include years 1945-1995

# Reset index after filtering
df = df.reset_index(drop=True)


df
# Out:
#            station                  name  prcp  snow  snwd   tmax   tmin  \
# 683    USC00461393  CANAAN VALLEY, WV US  0.45   3.0   NaN  42.98  33.08
# 684    USC00461393  CANAAN VALLEY, WV US   NaN   0.0   NaN  37.94  -2.02
# 685    USC00461393  CANAAN VALLEY, WV US   NaN   0.0   NaN  24.08   3.92
# 686    USC00461393  CANAAN VALLEY, WV US   NaN   0.0   NaN  35.96  28.94
# 687    USC00461393  CANAAN VALLEY, WV US   NaN   0.0   NaN  28.94  12.02
# ...            ...                   ...   ...   ...   ...    ...    ...
# 19301  USC00461393  CANAAN VALLEY, WV US   NaN   4.0   NaN  15.08  10.94
# 19302  USC00461393  CANAAN VALLEY, WV US   NaN   1.0   NaN  17.06  10.04
# 19303  USC00461393  CANAAN VALLEY, WV US  0.00   0.0   NaN  28.94   8.06
# 19304  USC00461393  CANAAN VALLEY, WV US  0.00   0.0   NaN  37.04  14.00
# 19305  USC00461393  CANAAN VALLEY, WV US  0.00   0.0   NaN  44.96  24.08
#
#           month   year day_of_month     y   m   d
# ...

# %%
# Plot the tmax data using a line graph.
# Use your new variable for year to have it display properly.

sns.lineplot(data=df, x='y', y=?, label='Precipitation')
# Out:
# <Axes: xlabel='y', ylabel='tmax'>

# %%
# Do we have any issues with missing samples in our data?

# Find the distinct years in the data by creating a set of the year column.
distinct_years = set(?)
print(f'Distinct years in the data: {distinct_years} ({len(distinct_years)} total)')

# Iterate through the distinct years, and count of the number of rows of data matching each year.
# Print the year and count of rows for each distinct year.
for ? in ?:
    # Create a filter for rows matching the current year
    df_years_matching_filter = df[?] == ?
    # Find all matching rows
    df_matching_rows = df[?]

    # Count the number of matching rows
    count = df_matching_rows.shape[0]
    print(?)
# Out:
# Distinct years in the data: {1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995} (51 total)
# Year: 1945, Count: 365
# Year: 1946, Count: 365
# Year: 1947, Count: 365
# Year: 1948, Count: 366
# Year: 1949, Count: 365
# Year: 1950, Count: 365
# Year: 1951, Count: 365
# Year: 1952, Count: 366
# Year: 1953, Count: 365
# Year: 1954, Count: 365
# Year: 1955, Count: 365
# Year: 1956, Count: 366
# Year: 1957, Count: 365
# Year: 1958, Count: 365
# Year: 1959, Count: 365
# Year: 1960, Count: 366
# Year: 1961, Count: 365
# Year: 1962, Count: 365
# Year: 1963, Count: 365
# Year: 1964, Count: 366
# Year: 1965, Count: 365
# Year: 1966, Count: 365
# Year: 1967, Count: 365
# Year: 1968, Count: 366
# Year: 1969, Count: 365
# Year: 1970, Count: 364
# ...

# %% [markdown]
# # How many records did we gather in 1995?
